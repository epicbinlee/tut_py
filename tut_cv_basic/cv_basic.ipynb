# %%
# pip install opencv-python==4.5.3.56
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
img = cv2.imread('pic.png')
# 读取灰度图
# img = cv2.imread('pic.png', cv2.IMREAD_GRAYSCALE)
# [H*W*C]
img.shape
# Out:
# (1290, 1806, 3)

# %%
# 方式1：imshow opencv-python-headless
def show_img(_name, _img):
    cv2.imshow(_name, _img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    cv2.waitKey(1)

# 方式2：默认格式BGR, matplotlib画图需要调整RGB

# %%
# 可视化图片
# show_img('img', img)

# %%
# =============================================================
# 读取视频 非常耗时
# vc = cv2.VideoCapture('/Users/leebin/Downloads/1.mkv/king.mkv')
# if vc.isOpened():
#     op, frame = vc.read()
# else:
#     op = False
# while op:
#     ret, frame = vc.read()
#     if frame is None:
#         break
#     if ret:
#         gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#         cv2.imshow('result', gray)
#         按 esc 就会停止
# if cv2.waitKey(1) & 0xFF == 27:
#     break
# vc.release()
# cv2.destroyWindow('result')

# %%
# =============================================================
# img = cv2.imread('pic.png', cv2.IMREAD_GRAYSCALE)
# print(img.shape)
# cat = img[0:50, 0:1200]
# show_img('sub_img', cat)

# %%
# 通道分离
img = cv2.imread('pic.png')
b, g, r = cv2.split(img)
# 通道合并
img = cv2.merge((b, g, r))
print(img.shape)
# show_img('pic', img)
plt.imshow(img)
# Out:
# (1290, 1806, 3)

# %%
# 单通道显示 b, g, r
cur_img = img.copy()
cur_img[:, :, 0] = 0
cur_img[:, :, 1] = 0
# show_img('R', cur_img)
plt.imshow(cur_img)

# %%
# 单通道显示
cur_img = img.copy()
cur_img[:, :, 0] = 0
cur_img[:, :, 2] = 0
# show_img('G', cur_img)
plt.imshow(cur_img)

# %%
# 单通道显示
cur_img = img.copy()
cur_img[:, :, 1] = 0
cur_img[:, :, 2] = 0
# show_img('B', cur_img)
plt.imshow(cur_img)

# %%
# =============================================================
# 边界填充
top_size, bottom_size, left_size, right_size = (50, 50, 50, 50)
replicate = cv2.copyMakeBorder(img, top_size, bottom_size, left_size, right_size, borderType=cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img, top_size, bottom_size, left_size, right_size, borderType=cv2.BORDER_REFLECT)
reflect_101 = cv2.copyMakeBorder(img, top_size, bottom_size, left_size, right_size, borderType=cv2.BORDER_REFLECT101)
wrap = cv2.copyMakeBorder(img, top_size, bottom_size, left_size, right_size, borderType=cv2.BORDER_WRAP)
constant = cv2.copyMakeBorder(img, top_size, bottom_size, left_size, right_size, borderType=cv2.BORDER_CONSTANT, value=0)
plt.subplot(231), plt.imshow(img, 'gray'), plt.title('top_size')
plt.subplot(232), plt.imshow(replicate, 'gray'), plt.title('replicate')
plt.subplot(233), plt.imshow(reflect, 'gray'), plt.title('reflect')
plt.subplot(234), plt.imshow(reflect_101, 'gray'), plt.title('reflect_101')
plt.subplot(235), plt.imshow(wrap, 'gray'), plt.title('wrap')
plt.subplot(236), plt.imshow(constant, 'gray'), plt.title('constant')
# Out:
# (<AxesSubplot: title={'center': 'constant'}>,
# ...
#  Text(0.5, 1.0, 'constant'))

# %%
# =============================================
# 自动取余数
img = cv2.imread('pic.png')
print(img.shape)
img = img + img
# show_img('pic', img)
plt.imshow(img)
# Out:
# (1290, 1806, 3)

# %%
# show_img('pic', cv2.add(img, img))

# %%
dog = cv2.imread('pic.png')
cat = cv2.imread('cat.png')
dog_ = cv2.resize(dog, (500, 400))
cat_ = cv2.resize(cat, (500, 400))
# show_img('dog_', dog_)
# show_img('cat_', cat_)
# 图像融合
res = cv2.addWeighted(dog_, 0.2, cat_, 0.8, 0)
# show_img('dog+cat', )
plt.imshow(res)

# %%
# cv2.imwrite()
